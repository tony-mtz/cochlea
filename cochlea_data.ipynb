# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/DRIVE/cochlea_center_csv.csv', 
                   names=['patient', 'LR', 'X','Y','Z'],
                   skiprows=[0])

# %%
#df.head()

# %%
dfL = df[df.LR.str.match('Left')]

# %%
dfR = df[df.LR.str.match('Right')]

# %%
hist = dfL.hist(column='X')
dfL.X.mean()
# Out:
# 155.3

# %%
hist = dfL.hist(column='Y')
dfL.Y.mean()
# Out:
# 220.21666666666667

# %%
hist = dfL.hist(column='Z')
dfL.Z.mean()
# Out:
# 23.266666666666666

# %%
hist = dfR.hist(column='X')
dfR.X.mean()
# Out:
# 350.53333333333336

# %%
hist = dfR.hist(column='Y')
dfR.Y.mean()
# Out:
# 219.63333333333333

# %%
hist = dfR.hist(column='Z')
dfR.Z.mean()
# Out:
# 24.75

# %%
# about 70x70x40
